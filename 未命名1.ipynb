# %% [markdown]
# # 工作需要
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 计算机网络：
# ![image.png](attachment:image.png)

# %%
（1）TCP协议和UDP协议的区别

# %% [markdown]
# # 数据库基础
# ![image.png](attachment:image.png)

# %% [markdown]
# # 面试问题
# ![image.png](attachment:image.png)

# %%
TCP和HTTP原理，HTTPS和HTTP区别，IP地址的分类，TCP与UDP的区别以及常见状态码。
python的深拷贝和钱拷贝。
数据库： 数据库范式，简单的命令，
linux：常用的查询端口好，种植进程之类指令。
